# %%
import os
import json
import pickle
import string
import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Add, Input, Masking, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard, CSVLogger

# %%
base_dir = r'C:\Users\UTKARSH\Desktop\visual intelligence'
data_dir = r'C:\Users\UTKARSH\Desktop\visual intelligence\data'
models_dir = r'C:\Users\UTKARSH\Desktop\visual intelligence\models'
pre_processed_data_dir = r'C:\Users\UTKARSH\Desktop\visual intelligence\pre_processed_data'

# %%
train_captions = os.path.join(pre_processed_data_dir, 'train_captions.txt')
test_captions = os.path.join(pre_processed_data_dir, 'test_captions.txt')
train_img_dir = os.path.join(data_dir, 'train')
test_img_dir = os.path.join(data_dir, 'test')

# %%
TOTAL_IMAGES_TRAIN = len(os.listdir(train_img_dir))
TOTAL_IMAGES_TEST = len(os.listdir(test_img_dir))
TOTAL_CAPTIONS_TRAIN = TOTAL_IMAGES_TRAIN * 5
TOTAL_CAPTIONS_TEST = TOTAL_IMAGES_TEST * 5

# %%
import image_captioning_utils as icu

extractor = icu.ImageFeatureExtractor()

# Step 1: Extract image features
# train_image_features = extractor.extract_features_for_directory(train_img_dir, limit=100)
# pickle.dump(train_image_features, open(os.path.join(pre_processed_data_dir, 'train_image_features_1.pkl'), 'wb'))
train_image_features = pickle.load(open(os.path.join(pre_processed_data_dir, 'train_image_features_1.pkl'), 'rb'))

# test_image_features = extractor.extract_features_for_directory(test_img_dir, limit=100)
# pickle.dump(test_image_features, open(os.path.join(pre_processed_data_dir, 'test_image_features_1.pkl'), 'wb'))
test_image_features = pickle.load(open(os.path.join(pre_processed_data_dir, 'test_image_features_1.pkl'), 'rb'))
# Out:
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
# Step 2: Process captions for the selected images
train_image_ids = list(train_image_features.keys())
train_processor = icu.CaptionProcessor(train_captions, train_image_ids)

test_image_ids = list(test_image_features.keys())
test_processor = icu.CaptionProcessor(test_captions, test_image_ids)

VOCAB_SIZE = len(train_processor.tokenizer.word_index) + 1
MAX_LEN = train_processor.max_len

# %%
# Step 3: Create sequences for training
X1, X2, y = train_processor.create_sequences(train_image_features, VOCAB_SIZE)

# %%
#Custom Model
def build_model(vocab_size, max_len):
    image_input = Input(shape=(2048,))  # 2048 features from InceptionV3
    image_dense = Dense(256, activation='relu')(image_input)
    # Image feature input

    # Sequence input
    seq_input = Input(shape=(max_len,))
    seq_masking = Masking(mask_value=0)(seq_input)
    seq_embedding = Embedding(vocab_size, 256, mask_zero=False)(seq_masking)
    
    # Stacking three LSTM layers
    lstm_1 = LSTM(256, return_sequences=True, name="lstm_layer_1")(seq_embedding)
    lstm_2 = LSTM(256, return_sequences=True, name="lstm_layer_2")(lstm_1)
    lstm_3 = LSTM(256, name="lstm_layer_3")(lstm_2)

    # Combine the inputs
    combined = Add()([image_dense, lstm_3])
    output = Dense(vocab_size, activation='softmax')(combined)

    model = Model(inputs=[image_input, seq_input], outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy')
    return model

# %%
from tensorflow.keras.layers import (
    Input, Dense, Embedding, Add, LayerNormalization, Dropout, MultiHeadAttention, GlobalAveragePooling1D
)
from tensorflow.keras.models import Model
import tensorflow as tf

# Custom Transformer-based model
def transformer_encoder(inputs, num_heads, ff_dim, dropout_rate):
    # Multi-head self-attention
    attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1])(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = Add()([inputs, attention_output])  # Residual connection
    attention_output = LayerNormalization(epsilon=1e-6)(attention_output)

    # Feed-forward network
    ff_output = Dense(ff_dim, activation="relu")(attention_output)
    ff_output = Dense(inputs.shape[-1])(ff_output)
    ff_output = Dropout(dropout_rate)(ff_output)
    encoder_output = Add()([attention_output, ff_output])  # Residual connection
    encoder_output = LayerNormalization(epsilon=1e-6)(encoder_output)

    return encoder_output

def build_model(vocab_size, max_len, num_heads=8, ff_dim=512, num_layers=3, dropout_rate=0.1):
    # Image feature input
    image_input = Input(shape=(2048,), name="image_input")  # 2048 features from InceptionV3
    image_dense = Dense(256, activation='relu')(image_input)

    # Sequence input
    seq_input = Input(shape=(max_len,), name="seq_input")
    seq_embedding = Embedding(vocab_size, 256)(seq_input)

    # Adding positional encoding
    positions = tf.range(start=0, limit=max_len, delta=1)
    pos_encoding = Embedding(input_dim=max_len, output_dim=256)(positions)
    seq_embedding += pos_encoding

    # Stacking transformer encoder layers
    transformer_output = seq_embedding
    for _ in range(num_layers):
        transformer_output = transformer_encoder(transformer_output, num_heads, ff_dim, dropout_rate)

    # Pooling over the sequence dimension
    pooled_output = GlobalAveragePooling1D()(transformer_output)

    # Combine the inputs
    combined = Add()([image_dense, pooled_output])
    output = Dense(vocab_size, activation='softmax')(combined)

    # Model definition
    model = Model(inputs=[image_input, seq_input], outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy')
    return model

# %%
mymodel = build_model(VOCAB_SIZE, MAX_LEN)
mymodel.summary()
# plot_model(mymodel, show_shapes=True)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  seq_input (InputLayer)         [(None, 39)]         0           []
#
#  embedding_2 (Embedding)        (None, 39, 256)      249600      ['seq_input[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 39, 256)     0           ['embedding_2[0][0]']
#  da)
#
#  multi_head_attention (MultiHea  (None, 39, 256)     2103552     ['tf.__operators__.add[0][0]',
#  dAttention)                                                      'tf.__operators__.add[0][0]']
#
#  dropout (Dropout)              (None, 39, 256)      0           ['multi_head_attention[0][0]']
#
#  add_2 (Add)                    (None, 39, 256)      0           ['tf.__operators__.add[0][0]',
#                                                                   'dropout[0][0]']
#
#  layer_normalization (LayerNorm  (None, 39, 256)     512         ['add_2[0][0]']
#  alization)
#
#  dense_6 (Dense)                (None, 39, 512)      131584      ['layer_normalization[0][0]']
#
#  dense_7 (Dense)                (None, 39, 256)      131328      ['dense_6[0][0]']
#
#  dropout_1 (Dropout)            (None, 39, 256)      0           ['dense_7[0][0]']
#
#  add_3 (Add)                    (None, 39, 256)      0           ['layer_normalization[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 39, 256)     512         ['add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 39, 256)     2103552     ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 39, 256)      0           ['multi_head_attention_1[0][0]']
#
#  add_4 (Add)                    (None, 39, 256)      0           ['layer_normalization_1[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 39, 256)     512         ['add_4[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 39, 512)      131584      ['layer_normalization_2[0][0]']
#
#  dense_9 (Dense)                (None, 39, 256)      131328      ['dense_8[0][0]']
#
#  dropout_3 (Dropout)            (None, 39, 256)      0           ['dense_9[0][0]']
#
#  add_5 (Add)                    (None, 39, 256)      0           ['layer_normalization_2[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 39, 256)     512         ['add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 39, 256)     2103552     ['layer_normalization_3[0][0]',
#  eadAttention)                                                    'layer_normalization_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 39, 256)      0           ['multi_head_attention_2[0][0]']
#
#  add_6 (Add)                    (None, 39, 256)      0           ['layer_normalization_3[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 39, 256)     512         ['add_6[0][0]']
#  rmalization)
#
#  dense_10 (Dense)               (None, 39, 512)      131584      ['layer_normalization_4[0][0]']
#
#  dense_11 (Dense)               (None, 39, 256)      131328      ['dense_10[0][0]']
#
#  dropout_5 (Dropout)            (None, 39, 256)      0           ['dense_11[0][0]']
#
#  add_7 (Add)                    (None, 39, 256)      0           ['layer_normalization_4[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  image_input (InputLayer)       [(None, 2048)]       0           []
#
#  layer_normalization_5 (LayerNo  (None, 39, 256)     512         ['add_7[0][0]']
#  rmalization)
#
#  dense_5 (Dense)                (None, 256)          524544      ['image_input[0][0]']
#
#  global_average_pooling1d (Glob  (None, 256)         0           ['layer_normalization_5[0][0]']
#  alAveragePooling1D)
#
#  add_8 (Add)                    (None, 256)          0           ['dense_5[0][0]',
#                                                                   'global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_12 (Dense)               (None, 975)          250575      ['add_8[0][0]']
#
# ==================================================================================================
# Total params: 8,127,183
# Trainable params: 8,127,183
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = mymodel.fit([X1, X2], y, epochs=10, batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/10
# 73/73 [==============================] - 8s 73ms/step - loss: 5.5312 - val_loss: 5.6210
# Epoch 2/10
# 73/73 [==============================] - 5s 64ms/step - loss: 5.0519 - val_loss: 5.7515
# Epoch 3/10
# 73/73 [==============================] - 5s 64ms/step - loss: 4.7053 - val_loss: 5.7642
# Epoch 4/10
# 73/73 [==============================] - 5s 65ms/step - loss: 4.3387 - val_loss: 5.7729
# Epoch 5/10
# 73/73 [==============================] - 5s 65ms/step - loss: 4.0497 - val_loss: 6.0530
# Epoch 6/10
# 73/73 [==============================] - 5s 64ms/step - loss: 3.8872 - val_loss: 5.7832
# Epoch 7/10
# 73/73 [==============================] - 5s 64ms/step - loss: 3.7632 - val_loss: 5.9001
# Epoch 8/10
# 73/73 [==============================] - 5s 64ms/step - loss: 3.6707 - val_loss: 5.9598
# Epoch 9/10
# 73/73 [==============================] - 5s 69ms/step - loss: 3.6392 - val_loss: 5.7727
# Epoch 10/10
# 73/73 [==============================] - 5s 65ms/step - loss: 3.5986 - val_loss: 5.9458

# %%
def plot_history(history):

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(len(loss))

    plt.figure(figsize=(20, 5))
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.show()

# %%
plot_history(history)

# %%
mymodel.save(os.path.join(models_dir,'custom_model_1.h5'))
load_model = load_model(os.path.join(models_dir,'custom_model_1.h5'))

# %%
# Step 5: Test caption generation on a new image

model = load_model
random_id = np.random.choice(list(test_processor.captions_dict.keys()))
cap_id = random_id
test_image_path = os.path.join(test_img_dir, cap_id +'.jpg')
test_image_feature = extractor.extract_features(test_image_path)
test_image_feature = np.squeeze(test_image_feature)
generated_caption = icu.generate_caption(model, np.array([test_image_feature]), test_processor.tokenizer, MAX_LEN)

print("Actual Caption: ----------------------------")
for cap in test_processor.captions_dict[cap_id]:
  print(cap)
print("--------------------------------------------")

print("Generated Caption: ", generated_caption)

# Display the image
img = Image.open(test_image_path)
plt.imshow(img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 36ms/step
# Actual Caption: ----------------------------
# startseq Three teddy bears  each a different color  snuggling together endseq
# startseq Three stuffed animals are sitting on a bed endseq
# startseq Three teddy bears giving each other a hug endseq
# startseq A group of three stuffed animal teddy bears endseq
# startseq Three stuffed bears hugging and sitting on a blue pillow endseq
# --------------------------------------------
# Generated Caption:  startseq a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a

# %%
# Step 5: Train caption generation on a new image

model = load_model
random_id = np.random.choice(list(train_processor.captions_dict.keys()))
cap_id = random_id
train_image_path = os.path.join(train_img_dir, cap_id +'.jpg')
train_image_feature = extractor.extract_features(train_image_path)
train_image_feature = np.squeeze(train_image_feature)
generated_caption = icu.generate_caption(model, np.array([train_image_feature]), train_processor.tokenizer, MAX_LEN)

print("Actual Caption: ----------------------------")
for cap in train_processor.captions_dict[cap_id]:
  print(cap)
print("--------------------------------------------")

print("Generated Caption: ", generated_caption)

# Display the image
img = Image.open(train_image_path)
plt.imshow(img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Actual Caption: ----------------------------
# startseq Three men in military suits are sitting on a bench endseq
# startseq Three persons with military attire seated on a bench endseq
# startseq Three young men in decorated uniforms sit on a bench together endseq
# startseq A few guys sit next to each other on a bench endseq
# startseq Three young men sitting on a bench wearing dress formals endseq
# --------------------------------------------
# Generated Caption:  startseq a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def calculate_bleu(test_features, test_captions, model, tokenizer, MAX_LEN):
    
    bleu_1_scores = []
    bleu_2_scores = []
    bleu_3_scores = []
    bleu_4_scores = []
    
    for image_id, image_features in test_features.items():
        predicted_caption = icu.generate_caption(model, np.array([image_features]), tokenizer, MAX_LEN)
        predicted_caption = predicted_caption.split()
        
        # Get the list of ground truth captions for this image
        reference_captions = [caption.split() for caption in test_captions[image_id]]
        
        # Smoothing function for higher n-grams
        smooth_fn = SmoothingFunction().method1

        # BLEU-1 (Unigrams)
        bleu_1 = sentence_bleu(reference_captions, predicted_caption, weights=(1, 0, 0, 0), smoothing_function=smooth_fn)
        
        # BLEU-2 (Unigrams + Bigrams)
        bleu_2 = sentence_bleu(reference_captions, predicted_caption, weights=(0.5, 0.5, 0, 0), smoothing_function=smooth_fn)
        
        # BLEU-3 (Unigrams + Bigrams + Trigrams)
        bleu_3 = sentence_bleu(reference_captions, predicted_caption, weights=(0.33, 0.33, 0.33, 0), smoothing_function=smooth_fn)
        
        # BLEU-4 (Unigrams + Bigrams + Trigrams + 4-grams)
        bleu_4 = sentence_bleu(reference_captions, predicted_caption, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smooth_fn)

        #Storing BLEU-1,BLEU-2,BLEU-3,BLEU-4
        bleu_1_scores.append(bleu_1)
        bleu_2_scores.append(bleu_2)
        bleu_3_scores.append(bleu_3)
        bleu_4_scores.append(bleu_4)
        
    #Return the average BLEU score across all test images
    return [np.mean(bleu_1_scores),np.mean(bleu_2_scores),np.mean(bleu_3_scores),np.mean(bleu_4_scores)]

# %%
bleu_score = calculate_bleu(test_image_features, test_processor.captions_dict, model, test_processor.tokenizer, MAX_LEN)
print(f"Average BLEU-1 Score on Test Dataset: {bleu_score[0]:.4f}")
print(f"Average BLEU-2 Score on Test Dataset: {bleu_score[1]:.4f}")
print(f"Average BLEU-3 Score on Test Dataset: {bleu_score[2]:.4f}")
print(f"Average BLEU-4 Score on Test Dataset: {bleu_score[3]:.4f}")
# Out:
# Average BLEU-1 Score on Test Dataset: 0.0683
# Average BLEU-2 Score on Test Dataset: 0.0131
# Average BLEU-3 Score on Test Dataset: 0.0080
# Average BLEU-4 Score on Test Dataset: 0.0059
